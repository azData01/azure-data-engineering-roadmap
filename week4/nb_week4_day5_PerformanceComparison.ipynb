# %%
# %%sql
# select * FROM dbo.bronze_customers;
#
# select * FROM dbo.silver_customers;
#
# select * FROM dbo.gold_customers_dim;
# Out:
# StatementMeta(, 75cc419d-e2b0-46d2-9452-6175e913ff91, 10, Finished, Available, Finished)
# <Spark SQL result set with 50 rows and 3 fields>
# <Spark SQL result set with 50 rows and 3 fields>
# <Spark SQL result set with 50 rows and 5 fields>
