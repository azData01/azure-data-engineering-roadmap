# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
tables = ["bronze_customers", "silver_customers", "gold_customers_dim", "gold_customer_signups_by_month"]

#for t in tables:
#    print("Table:", t)
#    spark.sql(f"DESCRIBE DETAIL {t}").select("name","format","location","numFiles","sizeInBytes").show(truncate=False)


#spark.sql("OPTIMIZE gold_customers_dim")
#spark.sql("OPTIMIZE silver_customers")

#spark.sql("VACUUM gold_customers_dim RETAIN 168 HOURS")  # 7 days
#spark.sql("VACUUM silver_customers RETAIN 168 HOURS")

for t in tables:
    spark.sql(f"DESCRIBE DETAIL {t}").select("name","numFiles","sizeInBytes").show(truncate=False)
# Out:
# StatementMeta(, 1ae81eb2-2566-4f0b-9a76-180455d7bde3, 6, Finished, Available, Finished)
# +-------------------------------------------------------------------------------------------------------+--------+-----------+
# |name                                                                                                   |numFiles|sizeInBytes|
# +-------------------------------------------------------------------------------------------------------+--------+-----------+
# |spark_catalog.chimcobldhq2alr5cllj8nr1f923ec1gbthmgprgegimoobbclk6utbjclbmapbb6gim8ojf.bronze_customers|1       |2963       |
# +-------------------------------------------------------------------------------------------------------+--------+-----------+
#
# +-------------------------------------------------------------------------------------------------------+--------+-----------+
# |name                                                                                                   |numFiles|sizeInBytes|
# +-------------------------------------------------------------------------------------------------------+--------+-----------+
# |spark_catalog.chimcobldhq2alr5cllj8nr1f923ec1gbthmgprgegimoobbclk6utbjclbmapbb6gim8ojf.silver_customers|1       |2808       |
# +-------------------------------------------------------------------------------------------------------+--------+-----------+
#
# +---------------------------------------------------------------------------------------------------------+--------+-----------+
# |name                                                                                                     |numFiles|sizeInBytes|
# +---------------------------------------------------------------------------------------------------------+--------+-----------+
# |spark_catalog.chimcobldhq2alr5cllj8nr1f923ec1gbthmgprgegimoobbclk6utbjclbmapbb6gim8ojf.gold_customers_dim|1       |3848       |
# +---------------------------------------------------------------------------------------------------------+--------+-----------+
#
# +---------------------------------------------------------------------------------------------------------------------+--------+-----------+
# |name                                                                                                                 |numFiles|sizeInBytes|
# +---------------------------------------------------------------------------------------------------------------------+--------+-----------+
# |spark_catalog.chimcobldhq2alr5cllj8nr1f923ec1gbthmgprgegimoobbclk6utbjclbmapbb6gim8ojf.gold_customer_signups_by_month|1       |1877       |
# +---------------------------------------------------------------------------------------------------------------------+--------+-----------+
