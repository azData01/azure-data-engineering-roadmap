# %%
# Welcome to your new notebook

# 1) Read CSV from Lakehouse Files area
df = spark.read.option("header", "true").csv("Files/customers.csv")

# 2) Quick check
display(df)

# 3) Write as Delta table in Lakehouse (Bronze)
df.write.mode("overwrite").format("delta").saveAsTable("bronze_customers")
# Out:
# StatementMeta(, c5907c35-a7e0-4a3d-a1db-4eaca566982b, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 08b77d65-7a4b-4c94-9467-71473bcb3dc8)
